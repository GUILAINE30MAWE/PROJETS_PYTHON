# %% [markdown]
# <p><font size="6"><b>03 - Pandas: Indexing and selecting data</b></font></p>

# %%
import pandas as pd

# %%
# redefining the example objects

# series
population = pd.Series({'Germany': 81.3, 'Belgium': 11.3, 'France': 64.3, 
                        'United Kingdom': 64.9, 'Netherlands': 16.9})

# dataframe
data = {'country': ['Belgium', 'France', 'Germany', 'Netherlands', 'United Kingdom'],
        'population': [11.3, 64.3, 81.3, 16.9, 64.9],
        'area': [30510, 671308, 357050, 41526, 244820],
        'capital': ['Brussels', 'Paris', 'Berlin', 'Amsterdam', 'London']}
countries = pd.DataFrame(data)
countries
# Out:
#           country  population    area    capital
# 0         Belgium        11.3   30510   Brussels
# 1          France        64.3  671308      Paris
# 2         Germany        81.3  357050     Berlin
# 3     Netherlands        16.9   41526  Amsterdam
# 4  United Kingdom        64.9  244820     London

# %%
countries
# Out:
#           country  population    area    capital
# 0         Belgium        11.3   30510   Brussels
# 1          France        64.3  671308      Paris
# 2         Germany        81.3  357050     Berlin
# 3     Netherlands        16.9   41526  Amsterdam
# 4  United Kingdom        64.9  244820     London

# %% [markdown]
# Setting the index to the country names:

# %%
countries = countries.set_index('country') #### Changer l'index du df et de passer ici la varible country enindex
countries
# Out:
#                 population    area    capital
# country
# Belgium               11.3   30510   Brussels
# France                64.3  671308      Paris
# Germany               81.3  357050     Berlin
# Netherlands           16.9   41526  Amsterdam
# United Kingdom        64.9  244820     London

# %%
countries ### index country ici
# Out:
#                 population    area    capital
# country
# Belgium               11.3   30510   Brussels
# France                64.3  671308      Paris
# Germany               81.3  357050     Berlin
# Netherlands           16.9   41526  Amsterdam
# United Kingdom        64.9  244820     London

# %%
countries.reset_index() #### Afficher l'index par défaut
# Out:
#           country  population    area    capital
# 0         Belgium        11.3   30510   Brussels
# 1          France        64.3  671308      Paris
# 2         Germany        81.3  357050     Berlin
# 3     Netherlands        16.9   41526  Amsterdam
# 4  United Kingdom        64.9  244820     London

# %%
countries.reset_index(inplace = True) ### Inplace = True qui permet d sauvegarder le changement en

# %%
countries #### Index auto incrementé
# Out:
#                 population    area    capital
# country
# Belgium               11.3   30510   Brussels
# France                64.3  671308      Paris
# Germany               81.3  357050     Berlin
# Netherlands           16.9   41526  Amsterdam
# United Kingdom        64.9  244820     London

# %%
countries.reset_index(inplace = True)

# %%
countries.set_index("country", inplace = True) #### Sauvegarder l'objet en mémoire

# %%
countries
# Out:
#                 population    area    capital
# country
# Belgium               11.3   30510   Brussels
# France                64.3  671308      Paris
# Germany               81.3  357050     Berlin
# Netherlands           16.9   41526  Amsterdam
# United Kingdom        64.9  244820     London

# %% [markdown]
# # Selecting data

# %% [markdown]
# <div class="alert alert-warning" style="font-size:120%">
# <b>ATTENTION!</b>: <br><br>
#
# One of pandas' basic features is the labeling of rows and columns, but this makes indexing also a bit more complex compared to numpy. <br><br> We now have to distuinguish between:
#
#  <ul>
#   <li>selection by **label** (using the row and column names)</li>
#   <li>selection by **position** (using integers)</li>
# </ul>
# </div>

# %% [markdown]
# ## `data[]` provides some convenience shortcuts

# %% [markdown]
# For a DataFrame, basic indexing selects the columns (cfr. the dictionaries of pure python)
#
# Selecting a **single column**:

# %%
countries
# Out:
#                 population    area    capital
# country
# Belgium               11.3   30510   Brussels
# France                64.3  671308      Paris
# Germany               81.3  357050     Berlin
# Netherlands           16.9   41526  Amsterdam
# United Kingdom        64.9  244820     London

# %%
countries["area"] # single [] #### Récupération d'une seule colonne dans notre df
# Out:
# country
# Belgium            30510
# France            671308
# Germany           357050
# Netherlands        41526
# United Kingdom    244820
# Name: area, dtype: int64

# %% [markdown]
# or multiple **columns**:

# %%
countries[["population","area"]] ### récupération des deux colonnes que sont population et area
# Out:
#                 population    area
# country
# Belgium               11.3   30510
# France                64.3  671308
# Germany               81.3  357050
# Netherlands           16.9   41526
# United Kingdom        64.9  244820

# %%
countries[["population","area"]]
# Out:
#                 population    area
# country
# Belgium               11.3   30510
# France                64.3  671308
# Germany               81.3  357050
# Netherlands           16.9   41526
# United Kingdom        64.9  244820

# %%
countries[['area', 'population']] # double [[]] #### Récupération de plusieur colonnes du df
# Out:
#                   area  population
# country
# Belgium          30510        11.3
# France          671308        64.3
# Germany         357050        81.3
# Netherlands      41526        16.9
# United Kingdom  244820        64.9

# %% [markdown]
# But, slicing or boolean indexing accesses the **rows**:

# %%
countries['France':'Netherlands'] ### Opère sur les lignes --> récupérer les pays de France à Netherlands
# Out:
#              population    area    capital
# country
# France             64.3  671308      Paris
# Germany            81.3  357050     Berlin
# Netherlands        16.9   41526  Amsterdam

# %%
countries['Belgium':'Netherlands']
# Out:
#              population    area    capital
# country
# Belgium            11.3   30510   Brussels
# France             64.3  671308      Paris
# Germany            81.3  357050     Berlin
# Netherlands        16.9   41526  Amsterdam

# %% [markdown]
# #### Filter sur les lignes (num ou str)

# %%
countries["area"] >300000  ### Etape 1 : Vérifier la proposition area > 30000
# Out:
# country
# Belgium           False
# France             True
# Germany            True
# Netherlands       False
# United Kingdom    False
# Name: area, dtype: bool

# %%
countries[countries["area"] >300000] #### Etape 2 : Afficher l'ensemble des pays quivérifient cette condition
# Out:
#          population    area capital
# country
# France         64.3  671308   Paris
# Germany        81.3  357050  Berlin

# %%
countries[countries['population'] > 50]
# Out:
#                 population    area capital
# country
# France                64.3  671308   Paris
# Germany               81.3  357050  Berlin
# United Kingdom        64.9  244820  London

# %% [markdown]
# <div class="alert alert-danger">
# <b>NOTE</b>:
#
#  <ul>
#   <li>Unlike slicing in numpy, the end label is **included**!</li>
# </ul>
# </div>

# %% [markdown]
# <div class="alert alert-info" style="font-size:120%">
# <b>REMEMBER</b>: <br><br>
#
# So as a summary, `[]` provides the following convenience shortcuts:
#
# <ul>
#   <li>**Series**: selecting a **label**: `s[label]`</li>
#   <li>**DataFrame**: selecting a single or multiple **columns**: `df['col']` or `df[['col1', 'col2']]`</li>
#   <li>**DataFrame**: slicing or filtering the **rows**: `df['row_label1':'row_label2']` or `df[mask]`</li>
# </ul>
# </div>

# %% [markdown]
# ## Systematic indexing with `loc` and `iloc`

# %%
countries
# Out:
#                 population    area    capital
# country
# Belgium               11.3   30510   Brussels
# France                64.3  671308      Paris
# Germany               81.3  357050     Berlin
# Netherlands           16.9   41526  Amsterdam
# United Kingdom        64.9  244820     London

# %% [markdown]
# When using `[]` like above, you can only select from one axis at once (rows or columns, not both). For more advanced indexing, you have some extra attributes:
#
# * `loc`: selection by label
# * `iloc`: selection by position
#
# Both `loc` and `iloc` use the following pattern: `df.loc[ <selection of the rows> , <selection of the columns> ]`.
#
# This 'selection of the rows / columns' can be: a single label, a list of labels, a slice or a boolean mask.

# %% [markdown]
# Selecting a single element:

# %%
countries
# Out:
#                 population    area    capital
# country
# Belgium               11.3   30510   Brussels
# France                64.3  671308      Paris
# Germany               81.3  357050     Berlin
# Netherlands           16.9   41526  Amsterdam
# United Kingdom        64.9  244820     London

# %%
countries.loc["Germany",:] #### Opération sur les lignes: Récupérer l'ensemble des informations de la ligne Germany
# Out:
# population      81.3
# area          357050
# capital       Berlin
# Name: Germany, dtype: object

# %%
countries.loc[:,"area"] ### Opération sur les colonnes: récupation de l'ensemble des lignes associée
# Out:
# country
# Belgium            30510
# France            671308
# Germany           357050
# Netherlands        41526
# United Kingdom    244820
# Name: area, dtype: int64

# %%
countries.loc["Germany", "area"] #### Opération sur les lignes et colonnes: Superficie de l'allemagne
# Out:
# 357050

# %%
#### Récupérer plusieurs élements

# %%
countries.loc["Germany":"United Kingdom", ["population","area"]] #### Plusieur élement dans un dataframe
# Out:
#                 population    area
# country
# Germany               81.3  357050
# Netherlands           16.9   41526
# United Kingdom        64.9  244820

# %%
countries.columns #### Connaitre le nom des colonnes
# Out:
# Index(['pop', 'surface', 'capital'], dtype='object')

# %%
countries.rename??

# %%
countries.rename(columns = {"population":"pop","area":"surface"}, inplace = True)  #### Sauvegarde des élements en mémoire

# %%
countries
# Out:
#                  pop  surface    capital
# country
# Belgium         11.3    30510   Brussels
# France          64.3   671308      Paris
# Germany         81.3   357050     Berlin
# Netherlands     16.9    41526  Amsterdam
# United Kingdom  64.9   244820     London

# %% [markdown]
# But the row or column indexer can also be a list, slice, boolean array (see next section), ..

# %%
countries.loc['France':'Germany', ['surface', 'pop']] ### Plusieurs élement avec Python
# Out:
#          surface   pop
# country
# France    671308  64.3
# Germany   357050  81.3

# %%
countries
# Out:
#           country  population    area    capital
# 0         Belgium        11.3   30510   Brussels
# 1          France        64.3  671308      Paris
# 2         Germany        81.3  357050     Berlin
# 3     Netherlands        16.9   41526  Amsterdam
# 4  United Kingdom        64.9  244820     London

# %% [markdown]
# ---
# Selecting by position with `iloc` works similar as **indexing numpy arrays**:

# %%
countries.iloc[2:,1:]  #### Les élements de a ligne Germany à UK et les colonnes surface et capital
# Out:
#    population    area    capital
# 2        81.3  357050     Berlin
# 3        16.9   41526  Amsterdam
# 4        64.9  244820     London

# %%
countries.iloc[0:2,1:3] #### Point d'arrivé en Python: Affiche Toujours n + 1 mais on ne récupère que n élement
# Out:
#    population    area
# 0        11.3   30510
# 1        64.3  671308

# %% [markdown]
# The different indexing methods can also be used to **assign data**:

# %%
countries
# Out:
#                  pop  surface    capital
# country
# Belgium         11.3    30510   Brussels
# France          64.3   671308      Paris
# Germany         81.3   357050     Berlin
# Netherlands     16.9    41526  Amsterdam
# United Kingdom  64.9   244820     London

# %%
countries.loc["Germany","surface"]  #### Avec l'opérateur loc
# Out:
# 357050

# %%
countries.iloc[2,1] #### Avec l'opérateur iloc
# Out:
# 357050

# %%
countries2 = countries.copy()
countries2.loc['Belgium':'Germany', 'population'] = 10

# %%
countries2
# Out:
#                  pop  surface    capital  population
# country
# Belgium         11.3    30510   Brussels        10.0
# France          64.3   671308      Paris        10.0
# Germany         81.3   357050     Berlin        10.0
# Netherlands     16.9    41526  Amsterdam         NaN
# United Kingdom  64.9   244820     London         NaN

# %% [markdown]
# <div class="alert alert-info" style="font-size:120%">
# <b>REMEMBER</b>: <br><br>
#
# Advanced indexing with **loc** and **iloc**
#
#  <ul>
#   <li>**loc**: select by label: `df.loc[row_indexer, column_indexer]`</li>
#   <li>**iloc**: select by position: `df.iloc[row_indexer, column_indexer]`</li>
# </ul>
# </div>

# %% [markdown]
# ## Boolean indexing (filtering)

# %% [markdown]
# Often, you want to select rows based on a certain condition. This can be done with 'boolean indexing' (like a where clause in SQL) and comparable to numpy.
#
# The indexer (or boolean mask) should be 1-dimensional and the same length as the thing being indexed.

# %%
countries["pop"] > 50 #### Intérroge python
# Out:
# country
# Belgium           False
# France             True
# Germany            True
# Netherlands       False
# United Kingdom     True
# Name: pop, dtype: bool

# %%
countries[countries["pop"] > 50] #### Element qui vérifie cette proposition
# Out:
#                  pop  surface capital
# country
# France          64.3   671308   Paris
# Germany         81.3   357050  Berlin
# United Kingdom  64.9   244820  London

# %%
countries['area'] > 100000
# Out:
# country
# Belgium           False
# France             True
# Germany            True
# Netherlands       False
# United Kingdom     True
# Name: area, dtype: bool

# %%
countries[countries['area'] > 100000]
# Out:
#                 population    area capital
# country
# France                64.3  671308   Paris
# Germany               81.3  357050  Berlin
# United Kingdom        64.9  244820  London

# %% [markdown]
# <div class="alert alert-success">
# <b>EXERCISE</b>:
#
# <p>
# <ul>
#     <li>Add the population density as column to the DataFrame.</li>
# </ul>
# </p>
# Note: the population column is expressed in millions.
# </div>

# %%
countries["density"] = countries["pop"]*1000000/countries["surface"] ####Nombre d'habitant par km2

# %%
countries
# Out:
#                  pop  surface    capital     density
# country
# Belgium         11.3    30510   Brussels  370.370370
# France          64.3   671308      Paris   95.783158
# Germany         81.3   357050     Berlin  227.699202
# Netherlands     16.9    41526  Amsterdam  406.973944
# United Kingdom  64.9   244820     London  265.092721

# %% [markdown]
# <div class="alert alert-success">
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>Select the capital and the population column of those countries where the density is larger than 300</li>
# </ul>
# </div>

# %%
countries[countries["density"] > 300] #### Ensenble des pays dont la densité est > à 300
# Out:
#               pop  surface    capital     density
# country
# Belgium      11.3    30510   Brussels  370.370370
# Netherlands  16.9    41526  Amsterdam  406.973944

# %%
countries[countries["density"] > 300].loc[:,["capital", "pop"]]  #### Ensemble des pays dont la densité est > 300
# Out:
#                capital   pop
# country
# Belgium       Brussels  11.3
# Netherlands  Amsterdam  16.9

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>Add a column 'density_ratio' with the ratio of the population density to the average population density for all countries.</li>
# </ul>
# </div>

# %%
countries["density"].mean() #### densité moyenne des pays en europe
# Out:
# 273.1838790074409

# %%
countries["density_ratio"] = countries["density"] /countries["density"].mean()

# %%
countries
# Out:
#                  pop  surface    capital     density  density_ratio
# country
# Belgium         11.3    30510   Brussels  370.370370       1.355755
# France          64.3   671308      Paris   95.783158       0.350618
# Germany         81.3   357050     Berlin  227.699202       0.833502
# Netherlands     16.9    41526  Amsterdam  406.973944       1.489744
# United Kingdom  64.9   244820     London  265.092721       0.970382

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>Change the capital of the UK to Cambridge</li>
# </ul>
# </div>

# %%
countries.loc["United Kingdom","capital"] = "Cambridge" ### Changement de la capital par Cambridge

# %%
countries
# Out:
#                  pop  surface    capital     density  density_ratio
# country
# Belgium         11.3    30510   Brussels  370.370370       1.355755
# France          64.3   671308      Paris   95.783158       0.350618
# Germany         81.3   357050     Berlin  227.699202       0.833502
# Netherlands     16.9    41526  Amsterdam  406.973944       1.489744
# United Kingdom  64.9   244820  Cambridge  265.092721       0.970382

# %% [markdown]
# <div class="alert alert-success">
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>Select all countries whose population density is between 100 and 300 people/km²</li>
# </ul>
# </div>

# %%
countries["density"]
# Out:
# country
# Belgium           370.370370
# France             95.783158
# Germany           227.699202
# Netherlands       406.973944
# United Kingdom    265.092721
# Name: density, dtype: float64

# %%
(countries["density"] > 100) & (countries["density"] < 300) #### Intérogation de Python condition 1 et condition 2
# Out:
# country
# Belgium           False
# France            False
# Germany            True
# Netherlands       False
# United Kingdom     True
# Name: density, dtype: bool

# %%
countries[(countries["density"] > 100) & (countries["density"] < 300)] #### Afficher les élements qui vérifie la condition
# Out:
#                  pop  surface    capital     density  density_ratio
# country
# Germany         81.3   357050     Berlin  227.699202       0.833502
# United Kingdom  64.9   244820  Cambridge  265.092721       0.970382

# %% [markdown]
# # Some other essential methods: `isin` and `string` methods

# %% [markdown]
# The `isin` method of Series is very useful to select rows that may contain certain values:

# %%
s = countries['capital']

# %%
s.isin?

# %%
s.isin(['Berlin', 'London'])

# %% [markdown]
# This can then be used to filter the dataframe with boolean indexing:

# %%
countries[countries['capital'].isin(['Berlin', 'Cambridge'])]
# Out:
#                  pop  surface    capital     density  density_ratio
# country
# Germany         81.3   357050     Berlin  227.699202       0.833502
# United Kingdom  64.9   244820  Cambridge  265.092721       0.970382

# %% [markdown]
# Let's say we want to select all data for which the capital starts with a 'B'. In Python, when having a string, we could use the `startswith` method:

# %%
string = 'Berlin'

# %%
string.startswith('B')
# Out:
# True

# %% [markdown]
# In pandas, these are available on a Series through the `str` namespace:

# %%
countries['capital'].str.startswith('B') #### Ensemble des pays qui commencent par un B
# Out:
# country
# Belgium            True
# France            False
# Germany            True
# Netherlands       False
# United Kingdom    False
# Name: capital, dtype: bool

# %%
countries['capital'].str.startswith('Ber')
# Out:
# country
# Belgium           False
# France            False
# Germany            True
# Netherlands       False
# United Kingdom    False
# Name: capital, dtype: bool

# %%
countries[countries['capital'].str.startswith('Ber') ]
# Out:
#           pop  surface capital     density  density_ratio
# country
# Germany  81.3   357050  Berlin  227.699202       0.833502

# %% [markdown]
# For an overview of all string methods, see: http://pandas.pydata.org/pandas-docs/stable/api.html#string-handling

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>Select all countries that have capital names with more than 7 characters</li>
# </ul>
#
# </div>

# %%
countries['capital']
# Out:
# 0     Brussels
# 1        Paris
# 2       Berlin
# 3    Amsterdam
# 4       London
# Name: capital, dtype: object

# %%
countries['capital'].apply(len)
# Out:
# 0    8
# 1    5
# 2    6
# 3    9
# 4    6
# Name: capital, dtype: int64

# %%
countries[countries['capital'].str.len() > 7] #### Autrement
# Out:
#                  pop  surface    capital     density  density_ratio
# country
# Belgium         11.3    30510   Brussels  370.370370       1.355755
# Netherlands     16.9    41526  Amsterdam  406.973944       1.489744
# United Kingdom  64.9   244820  Cambridge  265.092721       0.970382

# %%
countries['capital'].apply(len) #### Ensemble des longueurs des capitales
# Out:
# country
# Belgium           8
# France            5
# Germany           6
# Netherlands       9
# United Kingdom    9
# Name: capital, dtype: int64

# %%
countries['capital'].apply(len) > 7 #### Etape 1: ? longeur supérieure à 7
# Out:
# country
# Belgium            True
# France            False
# Germany           False
# Netherlands        True
# United Kingdom     True
# Name: capital, dtype: bool

# %%
countries[countries['capital'].apply(len) > 7] #### Etape 2 : crochet pour afficher les Pays dont la longeur du nom de la capital est supérieur à 7
# Out:
#                  pop  surface    capital     density  density_ratio
# country
# Belgium         11.3    30510   Brussels  370.370370       1.355755
# Netherlands     16.9    41526  Amsterdam  406.973944       1.489744
# United Kingdom  64.9   244820  Cambridge  265.092721       0.970382

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>Select all countries that have capital names that contain the character sequence 'am'</li>
# </ul>
# </div>

# %%
countries['capital'].str.contains("am") #### Pays dont la capital contient la chaine de caratère "am"
# Out:
# country
# Belgium           False
# France            False
# Germany           False
# Netherlands        True
# United Kingdom     True
# Name: capital, dtype: bool

# %%
countries[countries['capital'].str.contains("am")] ### Ensemble de spays qui contiennen la chaine de caractère am
# Out:
#                  pop  surface    capital     density  density_ratio
# country
# Netherlands     16.9    41526  Amsterdam  406.973944       1.489744
# United Kingdom  64.9   244820  Cambridge  265.092721       0.970382

# %%
countries[countries["capital"].apply(lambda x : "am" in str(x))]
# Out:
#                  pop  surface    capital     density  density_ratio
# country
# Netherlands     16.9    41526  Amsterdam  406.973944       1.489744
# United Kingdom  64.9   244820  Cambridge  265.092721       0.970382

# %% [markdown]
# # Pitfall: chained indexing (and the 'SettingWithCopyWarning')

# %%
countries.loc['Belgium', 'capital'] = 'Ghent'

# %%
countries
# Out:
#                  pop  surface    capital     density  density_ratio
# country
# Belgium         11.3    30510      Ghent  370.370370       1.355755
# France          64.3   671308      Paris   95.783158       0.350618
# Germany         81.3   357050     Berlin  227.699202       0.833502
# Netherlands     16.9    41526  Amsterdam  406.973944       1.489744
# United Kingdom  64.9   244820  Cambridge  265.092721       0.970382

# %%
countries['capital']['Belgium'] = 'Antwerp'
# Out:
# <ipython-input-153-f99e101c5201>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   countries['capital']['Belgium'] = 'Antwerp'

# %%
countries
# Out:
#                  pop  surface    capital     density  density_ratio
# country
# Belgium         11.3    30510    Antwerp  370.370370       1.355755
# France          64.3   671308      Paris   95.783158       0.350618
# Germany         81.3   357050     Berlin  227.699202       0.833502
# Netherlands     16.9    41526  Amsterdam  406.973944       1.489744
# United Kingdom  64.9   244820  Cambridge  265.092721       0.970382

# %%
countries[countries['capital'] == 'Antwerp']['capital'] = 'Brussels'
# Out:
# <ipython-input-155-50ff5c336503>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   countries[countries['capital'] == 'Antwerp']['capital'] = 'Brussels'

# %%
countries
# Out:
#                  pop  surface    capital     density  density_ratio
# country
# Belgium         11.3    30510    Antwerp  370.370370       1.355755
# France          64.3   671308      Paris   95.783158       0.350618
# Germany         81.3   357050     Berlin  227.699202       0.833502
# Netherlands     16.9    41526  Amsterdam  406.973944       1.489744
# United Kingdom  64.9   244820  Cambridge  265.092721       0.970382

# %%
countries.loc[countries['capital'] == 'Antwerp', 'capital'] = 'Brussels' 
countries
# Out:
#                  pop  surface    capital     density  density_ratio
# country
# Belgium         11.3    30510   Brussels  370.370370       1.355755
# France          64.3   671308      Paris   95.783158       0.350618
# Germany         81.3   357050     Berlin  227.699202       0.833502
# Netherlands     16.9    41526  Amsterdam  406.973944       1.489744
# United Kingdom  64.9   244820  Cambridge  265.092721       0.970382

# %% [markdown]
# <div class="alert alert-info" style="font-size:120%">
#
# <b>REMEMBER!</b><br><br>
#
# What to do when encountering the *value is trying to be set on a copy of a slice from a DataFrame* error?
#
#  <ul>
#   <li>Use `loc` instead of chained indexing **if possible**!</li>
#   <li>Or `copy` explicitly if you don't want to change the original data.</li>
# </ul>
#
# </div>

# %% [markdown]
# # Exercises using the Titanic dataset

# %%
df = pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>Select all rows for male passengers and calculate the mean age of those passengers. Do the same for the female passengers.</li>
# </ul>
# </div>

# %%
df.groupby("Sex")[["Age"]].mean() #### Age moyen pour chaque genre
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
#### Sélectionner l'ensemble des individus de genre masculin

df["Sex"] =="male" #### Etape1: interoge Python
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
df[df["Sex"] =="male"] #### Etape 2: Afficher les individus correspondants
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df[df["Sex"] =="male"].loc[:,["Age"]].mean() #### Age des individus de genre masculin de 30.72 ans
# Out:
# Age    30.726645
# dtype: float64

# %%
df[df["Sex"] =="female"].loc[:,["Age"]].mean() #### Age des individus de genre feminin de 27.91 ans
# Out:
# Age    27.915709
# dtype: float64

# %%
df.groupby("Sex")[["Age"]].mean() #### Age moyen pour chaque genre
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
#### Avec iloc

df[df["Sex"] =="male"].iloc[:,5].mean() #### Age des individus de genre masculin de 30.72 ans
# Out:
# 30.72664459161148

# %%
df[df["Sex"] =="female"].iloc[:,5].mean()  #### Age des individus de genre feminin de 27.91 ans
# Out:
# 27.915708812260537

# %% [markdown]
# We will later see an easier way to calculate both averages at the same time with groupby.

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>How many passengers older than 70 were on the Titanic?</li>
# </ul>
# </div>

# %%
df[df["Age"] > 70] #### Sélectionner les individus dont l'age est supérieur à 70 ans
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
df[df["Age"] > 70].shape[0] #### La longueur de ces individus
# Out:
# 5

# %%
len(df[df["Age"] > 70]) #### La longueur de ces individus
# Out:
# 5

# %% [markdown]
# # [OPTIONAL] more exercises

# %%
cast = pd.read_csv('cast.csv')
cast.head()
# Out:
#                                title  year       name   type character     n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22.0
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself   NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27.0
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3.0
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself   NaN

# %%
titles = pd.read_csv('titles.csv')
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1        Ashes of Kukulcan  2016
# 2  The Thousand Plane Raid  1969
# 3         Crucea de piatra  1993
# 4                   The 86  2015

# %%
cast["name"].str.startswith("Leonardo") #### ? Etape 1: Ensemble des personne qui commencent par Léonardo
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 3333690    False
# 3333691    False
# 3333692    False
# 3333693    False
# 3333694    False
# Name: name, Length: 3333695, dtype: bool

# %%
cast[cast["name"].str.startswith("Leonardo Di") ] #### Résultat: Ensemble des films dont l'acteur s'appelle Léonardo
# Out:
#                                         title  year                 name  \
# 524017                      Le fate ignoranti  2001    Leonardo Di Gioia
# 527096                          Blood Diamond  2006    Leonardo DiCaprio
# 527097                           Body of Lies  2008    Leonardo DiCaprio
# 527098                    Catch Me If You Can  2002    Leonardo DiCaprio
# 527099                              Celebrity  1998    Leonardo DiCaprio
# 527100                             Critters 3  1991    Leonardo DiCaprio
# 527101                       Django Unchained  2012    Leonardo DiCaprio
# 527102                             Don's Plum  2001    Leonardo DiCaprio
# 527103                      Gangs of New York  2002    Leonardo DiCaprio
# 527104                              Inception  2010    Leonardo DiCaprio
# 527105                               J. Edgar  2011    Leonardo DiCaprio
# 527106                          Marvin's Room  1996    Leonardo DiCaprio
# ...

# %%
cast[cast["name"].str.startswith("Leonardo Di") ].loc[:,"name"].nunique()  #### Ici nunique() Le nombre de valeurs uniques de notre échantillon
# Out:
# 3

# %%
cast[cast["name"].str.startswith("Leonardo Di") ].loc[:,"name"].unique() #### Ici unique() Leurs modalités
# Out:
# array(['Leonardo Di Gioia', 'Leonardo DiCaprio', 'Leonardo Digirolamo'],
#       dtype=object)

# %%
cast[cast["name"].str.startswith("Leonardo Di") ][["name"]] #### Ici unique() Leurs modalités
# Out:
#                        name
# 524017    Leonardo Di Gioia
# 527096    Leonardo DiCaprio
# 527097    Leonardo DiCaprio
# 527098    Leonardo DiCaprio
# 527099    Leonardo DiCaprio
# 527100    Leonardo DiCaprio
# 527101    Leonardo DiCaprio
# 527102    Leonardo DiCaprio
# 527103    Leonardo DiCaprio
# 527104    Leonardo DiCaprio
# 527105    Leonardo DiCaprio
# 527106    Leonardo DiCaprio
# 527107    Leonardo DiCaprio
# 527108    Leonardo DiCaprio
# 527109    Leonardo DiCaprio
# 527110    Leonardo DiCaprio
# 527111    Leonardo DiCaprio
# 527112    Leonardo DiCaprio
# 527113    Leonardo DiCaprio
# 527114    Leonardo DiCaprio
# 527115    Leonardo DiCaprio
# 527116    Leonardo DiCaprio
# 527117    Leonardo DiCaprio
# 527118    Leonardo DiCaprio
# 527119    Leonardo DiCaprio
# 527120    Leonardo DiCaprio
# 527121    Leonardo DiCaprio
# 527122    Leonardo DiCaprio
# 527123    Leonardo DiCaprio
# 527124    Leonardo DiCaprio
# 527125    Leonardo DiCaprio
# 529984  Leonardo Digirolamo

# %%
#### Phase 2: Sélectionner l'ensemble des films associées à cet acteur "Leonardo DiCaprio"

# %%
cast[cast["name"]=="Leonardo DiCaprio"] #### sélection des films qui comprennent cet acteur
# Out:
#                                         title  year               name   type  \
# 527096                          Blood Diamond  2006  Leonardo DiCaprio  actor
# 527097                           Body of Lies  2008  Leonardo DiCaprio  actor
# 527098                    Catch Me If You Can  2002  Leonardo DiCaprio  actor
# 527099                              Celebrity  1998  Leonardo DiCaprio  actor
# 527100                             Critters 3  1991  Leonardo DiCaprio  actor
# 527101                       Django Unchained  2012  Leonardo DiCaprio  actor
# 527102                             Don's Plum  2001  Leonardo DiCaprio  actor
# 527103                      Gangs of New York  2002  Leonardo DiCaprio  actor
# 527104                              Inception  2010  Leonardo DiCaprio  actor
# 527105                               J. Edgar  2011  Leonardo DiCaprio  actor
# 527106                          Marvin's Room  1996  Leonardo DiCaprio  actor
# ...

# %%
cast[cast["name"]=="Leonardo DiCaprio"].shape #### NOmbre de films dans lequel cet acteur à joué
# Out:
# (30, 6)

# %%
cast[cast["name"]=="Leonardo DiCaprio"].sort_values("year") #### Trie par rapport à la variable year
# Out:
#                                         title  year               name   type  \
# 527100                             Critters 3  1991  Leonardo DiCaprio  actor
# 527108                             Poison Ivy  1992  Leonardo DiCaprio  actor
# 527125            What's Eating Gilbert Grape  1993  Leonardo DiCaprio  actor
# 527122                        This Boy's Life  1993  Leonardo DiCaprio  actor
# 527119                 The Quick and the Dead  1995  Leonardo DiCaprio  actor
# 527113                 The Basketball Diaries  1995  Leonardo DiCaprio  actor
# 527124                          Total Eclipse  1995  Leonardo DiCaprio  actor
# 527106                          Marvin's Room  1996  Leonardo DiCaprio  actor
# 527110                         Romeo + Juliet  1996  Leonardo DiCaprio  actor
# 527123                                Titanic  1997  Leonardo DiCaprio  actor
# 527118               The Man in the Iron Mask  1998  Leonardo DiCaprio  actor
# ...

# %%
leo = cast[cast["name"]=="Leonardo DiCaprio"]
leo
# Out:
#                                         title  year               name   type  \
# 527096                          Blood Diamond  2006  Leonardo DiCaprio  actor
# 527097                           Body of Lies  2008  Leonardo DiCaprio  actor
# 527098                    Catch Me If You Can  2002  Leonardo DiCaprio  actor
# 527099                              Celebrity  1998  Leonardo DiCaprio  actor
# 527100                             Critters 3  1991  Leonardo DiCaprio  actor
# 527101                       Django Unchained  2012  Leonardo DiCaprio  actor
# 527102                             Don's Plum  2001  Leonardo DiCaprio  actor
# 527103                      Gangs of New York  2002  Leonardo DiCaprio  actor
# 527104                              Inception  2010  Leonardo DiCaprio  actor
# 527105                               J. Edgar  2011  Leonardo DiCaprio  actor
# 527106                          Marvin's Room  1996  Leonardo DiCaprio  actor
# ...

# %%
leo[leo["n"] == 2.0] #### Filtrer sur les seconds
# Out:
#                               title  year               name   type  \
# 527106                Marvin's Room  1996  Leonardo DiCaprio  actor
# 527109           Revolutionary Road  2008  Leonardo DiCaprio  actor
# 527125  What's Eating Gilbert Grape  1993  Leonardo DiCaprio  actor
#
#             character    n
# 527106           Hank  2.0
# 527109  Frank Wheeler  2.0
# 527125    Arnie Grape  2.0

# %%
leo[leo["n"] >= 5.0] #### Les films tq l'acteur ne fait pas partie des acteurs pricipaux
# Out:
#                    title  year               name   type       character     n
# 527099         Celebrity  1998  Leonardo DiCaprio  actor  Brandon Darrow  93.0
# 527100        Critters 3  1991  Leonardo DiCaprio  actor            Josh   7.0
# 527108        Poison Ivy  1992  Leonardo DiCaprio  actor             Guy   9.0
# 527116  The Great Gatsby  2013  Leonardo DiCaprio  actor      Jay Gatsby  12.0

# %%
temp = cast[cast["name"]=="Leonardo DiCaprio"].sort_values("year").loc[:,"n"]
temp
# Out:
# 527100     7.0
# 527108     9.0
# 527125     2.0
# 527122     3.0
# 527119     4.0
# 527113     1.0
# 527124     1.0
# 527106     2.0
# 527110     1.0
# 527123     1.0
# 527118     1.0
# 527117     1.0
# 527099    93.0
# 527114     1.0
# 527102     4.0
# 527103     1.0
# 527098     1.0
# 527112     1.0
# 527115     1.0
# 527096     1.0
# 527109     2.0
# 527097     1.0
# 527107     NaN
# 527111     1.0
# 527104     1.0
# 527105     1.0
# 527101     3.0
# 527116    12.0
# 527121     1.0
# 527120     1.0
# Name: n, dtype: float64

# %%
temp[temp == 2.0]
# Out:
# 527125    2.0
# 527106    2.0
# 527109    2.0
# Name: n, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>How many movies are listed in the titles dataframe?</li>
# </ul>
#
# </div>

# %%
titles.sort_values("year")  #### Trie des données
# Out:
#                                                     title  year
# 165182                                         Miss Jerry  1894
# 85708   Reproduction of the Corbett and Fitzsimmons Fight  1897
# 115903     Reproduction of the Corbett and Jeffries Fight  1899
# 198354        Sharkey-McCoy Fight Reproduced in 10 Rounds  1899
# 12582                                Family Troubles (II)  1900
# ...                                                   ...   ...
# 26537                                   Spider in the Web  2022
# 185368                                  The Tree of Death  2022
# 40476                                               Rosie  2022
# 199790                                     New in Village  2024
# 44198                                           Wild Runs  2024
#
# [215981 rows x 2 columns]

# %%
len(titles)
# Out:
# 215981

# %%
titles["year"].min() #### Année la plus ancienne du df
# Out:
# 1894

# %%
titles["year"].max() ####Année la plus avancée du df
# Out:
# 2024

# %%
titles.shape[0]
# Out:
# 215981

# %%
titles.info() #### Le nombre de film au total
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215981 entries, 0 to 215980
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   title   215981 non-null  object
#  1   year    215981 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 3.3+ MB

# %%
#### Aparté: NOmbre de film après le moment de la constitution du df


titles[titles["year"] >=2017].sort_values("year").tail(15)
# Out:
#                                                   title  year
# 111620                       ArkhamAsylumFiles: Reunion  2020
# 148525               Fresh Zulus: The Krown - MCMLXXXII  2020
# 172563                                      The Hamster  2021
# 33273                                       Star Trek 5  2021
# 208454                                  Karma 50 Climax  2021
# 126383                                       Girl Fight  2021
# 1674                                       Edge of Time  2021
# 38641   Unity, Guardians Versus Corruption: War of Ages  2021
# 128097                 Let's Paint the World with Peace  2021
# 163348                                   Storms of Time  2021
# 26537                                 Spider in the Web  2022
# 40476                                             Rosie  2022
# 185368                                The Tree of Death  2022
# 44198                                         Wild Runs  2024
# ...

# %%
titles[titles["year"] >2017].shape[0]/255000
# Out:
# 0.001403921568627451

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>What are the earliest two films listed in the titles dataframe?</li>
# </ul>
# </div>

# %%
titles.sort_values("year", ascending = True) #### trie les films par ordre croissant
# Out:
#                                                     title  year
# 165182                                         Miss Jerry  1894
# 85708   Reproduction of the Corbett and Fitzsimmons Fight  1897
# 115903     Reproduction of the Corbett and Jeffries Fight  1899
# 198354        Sharkey-McCoy Fight Reproduced in 10 Rounds  1899
# 12582                                Family Troubles (II)  1900
# ...                                                   ...   ...
# 26537                                   Spider in the Web  2022
# 185368                                  The Tree of Death  2022
# 40476                                               Rosie  2022
# 199790                                     New in Village  2024
# 44198                                           Wild Runs  2024
#
# [215981 rows x 2 columns]

# %%
titles.sort_values("year", ascending = True).head(2) #### Afficher les deux films les plus anciens
# Out:
#                                                     title  year
# 165182                                         Miss Jerry  1894
# 85708   Reproduction of the Corbett and Fitzsimmons Fight  1897

# %%
titles.sort_values('year', ascending = True).head(2)
# Out:
#                                                     title  year
# 165182                                         Miss Jerry  1894
# 85708   Reproduction of the Corbett and Fitzsimmons Fight  1897

# %%
titles.sort_values('year', ascending = False).head(10)
# Out:
#                                                   title  year
# 199790                                   New in Village  2024
# 44198                                         Wild Runs  2024
# 40476                                             Rosie  2022
# 185368                                The Tree of Death  2022
# 26537                                 Spider in the Web  2022
# 128097                 Let's Paint the World with Peace  2021
# 1674                                       Edge of Time  2021
# 38641   Unity, Guardians Versus Corruption: War of Ages  2021
# 172563                                      The Hamster  2021
# 163348                                   Storms of Time  2021

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>How many movies have the title "Hamlet"?</li>
# </ul>
# </div>

# %%
titles["title"] =="Hamlet" #### Etape 1: Interogation
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 215976    False
# 215977    False
# 215978    False
# 215979    False
# 215980    False
# Name: title, Length: 215981, dtype: bool

# %%
titles[titles["title"] =="Hamlet"] #### Etape 2: sélectionner les films Hamlet
# Out:
#          title  year
# 5562    Hamlet  1948
# 26160   Hamlet  2016
# 37373   Hamlet  2015
# 42224   Hamlet  1990
# 43511   Hamlet  1910
# 68239   Hamlet  1954
# 85741   Hamlet  1976
# 87781   Hamlet  1987
# 87971   Hamlet  2000
# 91710   Hamlet  1921
# 114224  Hamlet  1969
# 154627  Hamlet  1913
# 163645  Hamlet  2009
# 169996  Hamlet  1964
# 186988  Hamlet  1996
# 192815  Hamlet  2011
# 195015  Hamlet  1911
# 205821  Hamlet  1973
# 207793  Hamlet  2014

# %%
titles[titles["title"] =="Hamlet"].sort_values("year", ascending = False) #### Hamlet dans le temps
# Out:
#          title  year
# 26160   Hamlet  2016
# 37373   Hamlet  2015
# 207793  Hamlet  2014
# 192815  Hamlet  2011
# 163645  Hamlet  2009
# 87971   Hamlet  2000
# 186988  Hamlet  1996
# 42224   Hamlet  1990
# 87781   Hamlet  1987
# 85741   Hamlet  1976
# 205821  Hamlet  1973
# 114224  Hamlet  1969
# 169996  Hamlet  1964
# 68239   Hamlet  1954
# 5562    Hamlet  1948
# 91710   Hamlet  1921
# 154627  Hamlet  1913
# 195015  Hamlet  1911
# 43511   Hamlet  1910

# %%
len(titles[titles["title"] =="Hamlet"].sort_values("year")) #### Au total 19 films Hamlet depuis 1910
# Out:
# 19

# %%
19/11 ### 2 hamlet par decennie
# Out:
# 1.7272727272727273

# %%
len(titles[titles['title'] == 'Hamlet'])

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>List all of the "Treasure Island" movies from earliest to most recent.</li>
# </ul>
# </div>

# %%
titles["title"] =="Treasure Island"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 215976    False
# 215977    False
# 215978    False
# 215979    False
# 215980    False
# Name: title, Length: 215981, dtype: bool

# %%
titles[titles["title"] =="Treasure Island"].sort_values("year")
# Out:
#                   title  year
# 191379  Treasure Island  1918
# 47769   Treasure Island  1920
# 192917  Treasure Island  1934
# 90175   Treasure Island  1950
# 104714  Treasure Island  1972
# 103646  Treasure Island  1973
# 190792  Treasure Island  1985
# 166675  Treasure Island  1999

# %%
titles[titles.title == 'Anna Karenina'].sort_values('year', ascending = False)
# Out:
#                 title  year
# 185671  Anna Karenina  2012
# 59136   Anna Karenina  1997
# 167163  Anna Karenina  1975
# 91932   Anna Karenina  1967
# 137834  Anna Karenina  1953
# 54309   Anna Karenina  1948
# 71424   Anna Karenina  1935
# 199353  Anna Karenina  1918
# 9191    Anna Karenina  1915
# 28792   Anna Karenina  1914

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>How many movies were made from 1950 through 1959?</li>
# </ul>
# </div>

# %%
titles[(titles['year'] >= 1950) & (titles['year'] <= 1959)] #### Après 1950 et avant 1959 inclus
# Out:
#                                          title  year
# 9                               Women's Prison  1955
# 37      La momia azteca contra el robot humano  1958
# 86                            Botta e risposta  1950
# 88                         Perdeu-se um Marido  1957
# 106                             Qiu yu can hua  1953
# ...                                        ...   ...
# 215856                    Tischlein, deck dich  1956
# 215890                        Some Like It Hot  1959
# 215915                             Black Widow  1951
# 215919                             Encrucijada  1956
# 215945                       Te sigo esperando  1952
#
# [12120 rows x 2 columns]

# %%
titles[(titles['year'] >= 1950) & (titles['year'] <= 1959)].loc[:,["year"]].sort_values("year").loc[:,"year"].unique() #### ? sur quel objet j'opère -> 10 modalités de la décénnie 50
# Out:
# array([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959],
#       dtype=int64)

# %%
titles[(titles['year'] >= 1950) & (titles['year'] <= 1959)].loc[:,["year"]].sort_values("year").loc[:,"year"].nunique() #### 10 années
# Out:
# 10

# %%
len(titles[(titles['year'] >= 1950) & (titles['year'] <= 1959)])
# Out:
# 12120

# %%
titles[(titles['year'] >= 1950) & (titles['year'] <= 1959)]

# %%
len(titles[(titles['year'] >= 1950) & (titles['year'] <= 1959)])

# %%
len(titles[titles['year'] // 10 == 195])

# %%
1956/10
# Out:
# 195.6

# %%
1956//10  ###En sortie: uniquement le quotient --> reste exclue Je veux uniquement les films tq le resultat de la division entière soit 195
# Out:
# 195

# %%
1991 //10
# Out:
# 199

# %%
1956  //10
# Out:
# 195

# %%
1961 //10
# Out:
# 196

# %%
titles["year"] //10 #### objet --> 3 chiffres ici on souhaite avoir les lignes tq ces chiffrs soit 195
# Out:
# 0         199
# 1         201
# 2         196
# 3         199
# 4         201
#          ...
# 215976    192
# 215977    201
# 215978    200
# 215979    201
# 215980    198
# Name: year, Length: 215981, dtype: int64

# %%
titles['year'] // 10 == 195 #### Ask Python chiffres issues de la division soit "195"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 215976    False
# 215977    False
# 215978    False
# 215979    False
# 215980    False
# Name: year, Length: 215981, dtype: bool

# %%
titles[titles['year'] // 10 ==195] ### Application du filtrage -> Ensemble des films tq appartenant à la dcenie 1950
# Out:
#                                          title  year
# 9                               Women's Prison  1955
# 37      La momia azteca contra el robot humano  1958
# 86                            Botta e risposta  1950
# 88                         Perdeu-se um Marido  1957
# 106                             Qiu yu can hua  1953
# ...                                        ...   ...
# 215856                    Tischlein, deck dich  1956
# 215890                        Some Like It Hot  1959
# 215915                             Black Widow  1951
# 215919                             Encrucijada  1956
# 215945                       Te sigo esperando  1952
#
# [12120 rows x 2 columns]

# %%
titles[titles['year'] // 10 == 195]
# Out:
#                                          title  year
# 9                               Women's Prison  1955
# 37      La momia azteca contra el robot humano  1958
# 86                            Botta e risposta  1950
# 88                         Perdeu-se um Marido  1957
# 106                             Qiu yu can hua  1953
# ...                                        ...   ...
# 215856                    Tischlein, deck dich  1956
# 215890                        Some Like It Hot  1959
# 215915                             Black Widow  1951
# 215919                             Encrucijada  1956
# 215945                       Te sigo esperando  1952
#
# [12120 rows x 2 columns]

# %%
len(titles[titles['year'] // 10 == 195])
# Out:
# 12120

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>How many roles in the movie "Inception" are NOT ranked by an "n" value?</li>
# </ul>
# </div>

# %%
cast[cast["title"] =="Inception"]
# Out:
#              title  year                  name     type  \
# 86093    Inception  2010  Michael (III) August    actor
# 131026   Inception  2010          Peter Basham    actor
# 162266   Inception  2010          Tom Berenger    actor
# 174676   Inception  2010              Ken Bhan    actor
# 230132   Inception  2010        Virgile Bramly    actor
# ...            ...   ...                   ...      ...
# 2992313  Inception  2010            Ellen Page  actress
# 3041671  Inception  2010        Nicole Pulliam  actress
# 3065822  Inception  2010    Lisa (II) Reynolds  actress
# 3071990  Inception  2010         Talulah Riley  actress
# 3286897  Inception  2010        Shannon Welles  actress
#
#                      character     n
# 86093            LAX Passenger   NaN
# 131026   Fischer's Jet Captain  44.0
# 162266                Browning   8.0
# 174676        Mombasan Gambler   NaN
# 230132          Bridge Sub Con  29.0
# ...                        ...   ...
# ...

# %%
inception = cast[cast['title'] == 'Inception']

# %%
inception[inception["n"].isnull()]
# Out:
#              title  year                     name     type  \
# 86093    Inception  2010     Michael (III) August    actor
# 174676   Inception  2010                 Ken Bhan    actor
# 333474   Inception  2010            John Ceallach    actor
# 610905   Inception  2010            Seve Esposito    actor
# 631993   Inception  2010  Zachary Christopher Fay    actor
# 747030   Inception  2010        Daniel Girondeaud    actor
# 900363   Inception  2010          Andrew Hoagland    actor
# 979629   Inception  2010          Charles Jarrell    actor
# 991536   Inception  2010            Seong-hwan Jo    actor
# 1001735  Inception  2010          Alonzo F. Jones    actor
# 1062541  Inception  2010               Mobin Khan    actor
# 1114025  Inception  2010            Shunsaku Kud?    actor
# 1156558  Inception  2010         John (IX) Lawson    actor
# 1170866  Inception  2010    Jean-Christophe Leger    actor
# 1487576  Inception  2010     Fran?ois-Marie Nivon    actor
# ...

# %%
len(inception[inception['n'].isnull()]) ### Nombre de personne dans le df
# Out:
# 22

# %%
inception['n'].isnull().sum() #### Nombre de personne non ranké dans le df
# Out:
# 22

# %%
cast[(cast["title"] == "Inception")&(cast["n"].notna() == False)].shape[0]
# Out:
# 22

# %%
#cast[cast["title"] =="Inception"]
# Out:
#              title  year                  name     type  \
# 86093    Inception  2010  Michael (III) August    actor
# 131026   Inception  2010          Peter Basham    actor
# 162266   Inception  2010          Tom Berenger    actor
# 174676   Inception  2010              Ken Bhan    actor
# 230132   Inception  2010        Virgile Bramly    actor
# ...            ...   ...                   ...      ...
# 2992313  Inception  2010            Ellen Page  actress
# 3041671  Inception  2010        Nicole Pulliam  actress
# 3065822  Inception  2010    Lisa (II) Reynolds  actress
# 3071990  Inception  2010         Talulah Riley  actress
# 3286897  Inception  2010        Shannon Welles  actress
#
#                      character     n
# 86093            LAX Passenger   NaN
# 131026   Fischer's Jet Captain  44.0
# 162266                Browning   8.0
# 174676        Mombasan Gambler   NaN
# 230132          Bridge Sub Con  29.0
# ...                        ...   ...
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>But how many roles in the movie "Inception" did receive an "n" value?</li>
# </ul>
# </div>

# %%
inception['n'].notnull()#### Ask python: estce que la variable n est nulle ?
# Out:
# 86093      False
# 131026      True
# 162266      True
# 174676     False
# 230132      True
#            ...
# 2992313     True
# 3041671     True
# 3065822     True
# 3071990     True
# 3286897     True
# Name: n, Length: 73, dtype: bool

# %%
inception[inception['n'].notnull()].sort_values("n")  #### Zfficher l'ensemble des élements qui vérifie cette propriété
# Out:
#              title  year                  name     type  \
# 527104   Inception  2010     Leonardo DiCaprio    actor
# 768037   Inception  2010  Joseph Gordon-Levitt    actor
# 2992313  Inception  2010            Ellen Page  actress
# 840696   Inception  2010             Tom Hardy    actor
# 2144359  Inception  2010          Ken Watanabe    actor
# 1674163  Inception  2010            Dileep Rao    actor
# 1443451  Inception  2010        Cillian Murphy    actor
# 162266   Inception  2010          Tom Berenger    actor
# 2457632  Inception  2010      Marion Cotillard  actress
# 1629851  Inception  2010    Pete Postlethwaite    actor
# 290277   Inception  2010         Michael Caine    actor
# 813300   Inception  2010            Lukas Haas    actor
# 1168652  Inception  2010            Tai-Li Lee    actor
# 2602057  Inception  2010          Claire Geare  actress
# 1490107  Inception  2010          Magnus Nolan    actor
# 2602064  Inception  2010          Taylor Geare  actress
# ...

# %%
len(inception[inception['n'].notnull()])
# Out:
# 51

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>Display the cast of the "Titanic" (the most famous 1997 one) in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.</li>
# </ul>
# </div>

# %%
cast["n"]
# Out:
# 0          22.0
# 1           NaN
# 2          27.0
# 3           3.0
# 4           NaN
#            ...
# 3333690    24.0
# 3333691    24.0
# 3333692    26.0
# 3333693    17.0
# 3333694     NaN
# Name: n, Length: 3333695, dtype: float64

# %%
cast["n"].isnull()
# Out:
# 0          False
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 3333690    False
# 3333691    False
# 3333692    False
# 3333693    False
# 3333694     True
# Name: n, Length: 3333695, dtype: bool

# %%
cast[(cast['title'] == 'Titanic') & (cast['year'] == 1997)] #### Filter sur Titanic en 1997
# Out:
#            title  year                  name     type  \
# 3766     Titanic  1997       Lewis Abernathy    actor
# 13229    Titanic  1997           Seth Adkins    actor
# 51012    Titanic  1997  Scott (XII) Anderson    actor
# 51528    Titanic  1997        Kris Andersson    actor
# 79144    Titanic  1997   Richard (II) Ashton    actor
# ...          ...   ...                   ...      ...
# 3191641  Titanic  1997         Gloria Stuart  actress
# 3270153  Titanic  1997        Alison Waddell  actress
# 3270155  Titanic  1997         Amber Waddell  actress
# 3304287  Titanic  1997          Kate Winslet  actress
# 3331091  Titanic  1997       Lucie Zolcerova  actress
#
#                          character      n
# 3766                  Lewis Bodine   13.0
# 13229     Slovakian 3 Year Old Boy   79.0
# 51012              Frederick Fleet   43.0
# 51528                       Dancer  108.0
# 79144    Carpenter John Hutchinson   59.0
# ...                            ...    ...
# ...

# %%
cast[(cast['title'] == 'Titanic') & (cast['year'] == 1997)].loc[:,"n"].isnull().sum() #### 38 personnes qur 150 qui n'ont pas de rang affecté
# Out:
# 38

# %%
titanic = cast[(cast['title'] == 'Titanic') & (cast['year'] == 1997)]
titanic
# Out:
#            title  year                  name     type  \
# 3766     Titanic  1997       Lewis Abernathy    actor
# 13229    Titanic  1997           Seth Adkins    actor
# 51012    Titanic  1997  Scott (XII) Anderson    actor
# 51528    Titanic  1997        Kris Andersson    actor
# 79144    Titanic  1997   Richard (II) Ashton    actor
# ...          ...   ...                   ...      ...
# 3191641  Titanic  1997         Gloria Stuart  actress
# 3270153  Titanic  1997        Alison Waddell  actress
# 3270155  Titanic  1997         Amber Waddell  actress
# 3304287  Titanic  1997          Kate Winslet  actress
# 3331091  Titanic  1997       Lucie Zolcerova  actress
#
#                          character      n
# 3766                  Lewis Bodine   13.0
# 13229     Slovakian 3 Year Old Boy   79.0
# 51012              Frederick Fleet   43.0
# 51528                       Dancer  108.0
# 79144    Carpenter John Hutchinson   59.0
# ...                            ...    ...
# ...

# %%
titanic = titanic[titanic['n'].notnull()] #### valeurs non NA
titanic
# Out:
#            title  year                  name     type  \
# 3766     Titanic  1997       Lewis Abernathy    actor
# 13229    Titanic  1997           Seth Adkins    actor
# 51012    Titanic  1997  Scott (XII) Anderson    actor
# 51528    Titanic  1997        Kris Andersson    actor
# 79144    Titanic  1997   Richard (II) Ashton    actor
# ...          ...   ...                   ...      ...
# 3088900  Titanic  1997         Rochelle Rose  actress
# 3191641  Titanic  1997         Gloria Stuart  actress
# 3270153  Titanic  1997        Alison Waddell  actress
# 3270155  Titanic  1997         Amber Waddell  actress
# 3304287  Titanic  1997          Kate Winslet  actress
#
#                          character      n
# 3766                  Lewis Bodine   13.0
# 13229     Slovakian 3 Year Old Boy   79.0
# 51012              Frederick Fleet   43.0
# 51528                       Dancer  108.0
# 79144    Carpenter John Hutchinson   59.0
# ...                            ...    ...
# ...

# %%
titanic.sort_values('n')
# Out:
#            title  year               name     type              character  \
# 527123   Titanic  1997  Leonardo DiCaprio    actor            Jack Dawson
# 3304287  Titanic  1997       Kate Winslet  actress    Rose DeWitt Bukater
# 2241466  Titanic  1997         Billy Zane    actor  Caledon 'Cal' Hockley
# 2323120  Titanic  1997        Kathy Bates  actress            Molly Brown
# 2567572  Titanic  1997     Frances Fisher  actress    Ruth Dewitt Bukater
# ...          ...   ...                ...      ...                    ...
# 2678999  Titanic  1997        Andie Hicks  actress                 Dancer
# 898633   Titanic  1997       Scott Hislop    actor                 Dancer
# 1315604  Titanic  1997         Stan Mazin    actor                 Dancer
# 3054629  Titanic  1997        Lisa Ratzin  actress                 Dancer
# 3062849  Titanic  1997       Julene Renee  actress                 Dancer
#
#              n
# 527123     1.0
# 3304287    2.0
# 2241466    3.0
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>List the supporting roles (having n=2) played by Brad Pitt in the 1990s, in order by year.</li>
# </ul>
# </div>

# %%
cast[cast['name'] == 'Brad Pitt'] #### Sélection de l'acteur
# Out:
#                                                      title  year       name  \
# 1614612                                   12 Years a Slave  2013  Brad Pitt
# 1614613                            A River Runs Through It  1992  Brad Pitt
# 1614614                                        Abby Singer  2003  Brad Pitt
# 1614615                                  Across the Tracks  1990  Brad Pitt
# 1614616                                              Babel  2006  Brad Pitt
# 1614617                               Being John Malkovich  1999  Brad Pitt
# 1614618                                 Burn After Reading  2008  Brad Pitt
# 1614619                                         By the Sea  2015  Brad Pitt
# 1614620                    Confessions of a Dangerous Mind  2002  Brad Pitt
# 1614621                                         Cool World  1992  Brad Pitt
# 1614622                                      Cutting Class  1989  Brad Pitt
# ...

# %%
brad = cast[cast['name'] == 'Brad Pitt']

# %%
brad = brad[brad['year'] // 10 == 199] #### Ensemble des films de brad pitt dans les année s1990
brad
# Out:
#                                                      title  year       name  \
# 1614613                            A River Runs Through It  1992  Brad Pitt
# 1614615                                  Across the Tracks  1990  Brad Pitt
# 1614617                               Being John Malkovich  1999  Brad Pitt
# 1614621                                         Cool World  1992  Brad Pitt
# 1614623                                         Fight Club  1999  Brad Pitt
# 1614630  Interview with the Vampire: The Vampire Chroni...  1994  Brad Pitt
# 1614631                                       Johnny Suede  1991  Brad Pitt
# 1614632                                         Kalifornia  1993  Brad Pitt
# 1614634                                Legends of the Fall  1994  Brad Pitt
# 1614637                                     Meet Joe Black  1998  Brad Pitt
# 1614638                                     Meet Joe Black  1998  Brad Pitt
# ...

# %%
brad = brad[brad['n'] == 2] #### parmis ces films brad + 1990: second roles ie n =2
brad
# Out:
#                            title  year       name   type  \
# 1614613  A River Runs Through It  1992  Brad Pitt  actor
# 1614615        Across the Tracks  1990  Brad Pitt  actor
# 1614623               Fight Club  1999  Brad Pitt  actor
# 1614657          The Devil's Own  1997  Brad Pitt  actor
# 1614658          The Devil's Own  1997  Brad Pitt  actor
#
#                       character    n
# 1614613            Paul Maclean  2.0
# 1614615             Joe Maloney  2.0
# 1614623            Tyler Durden  2.0
# 1614657            Rory Devaney  2.0
# 1614658  Francis Austin McGuire  2.0

# %%
brad.sort_values('year', inplace = True) #### trie par année pour ce dataset

# %%
brad
# Out:
#                            title  year       name   type  \
# 1614615        Across the Tracks  1990  Brad Pitt  actor
# 1614613  A River Runs Through It  1992  Brad Pitt  actor
# 1614657          The Devil's Own  1997  Brad Pitt  actor
# 1614658          The Devil's Own  1997  Brad Pitt  actor
# 1614623               Fight Club  1999  Brad Pitt  actor
#
#                       character    n
# 1614615             Joe Maloney  2.0
# 1614613            Paul Maclean  2.0
# 1614657            Rory Devaney  2.0
# 1614658  Francis Austin McGuire  2.0
# 1614623            Tyler Durden  2.0

# %%
#### Aparté: Il y a des doublons: Un acteur peut jouer deux ou plusieur rôles

brad["title"].unique()
# Out:
# array(['Across the Tracks', 'A River Runs Through It', "The Devil's Own",
#        'Fight Club'], dtype=object)

# %%
brad["title"].nunique()
# Out:
# 4

# %%
brad["character"].tolist() #### Optionnel
# Out:
# ['Joe Maloney',
#  'Paul Maclean',
#  'Rory Devaney',
#  'Francis Austin McGuire',
#  'Tyler Durden']

# %%
#### ici on affiche tous les films où Brad 
B_pitt = cast[(cast["name"]=="Brad Pitt")&(cast["year"] >= 1990)&(cast["year"] < 2000)].sort_values("year")
##### On affiche cette fois avec le second rôle (n=2) de l'acteur Brad Pitt dans les films des années 90
B_pitt = B_pitt[(B_pitt['n']==2)]
B_pitt
# Out:
#                            title  year       name   type  \
# 1614615        Across the Tracks  1990  Brad Pitt  actor
# 1614613  A River Runs Through It  1992  Brad Pitt  actor
# 1614657          The Devil's Own  1997  Brad Pitt  actor
# 1614658          The Devil's Own  1997  Brad Pitt  actor
# 1614623               Fight Club  1999  Brad Pitt  actor
#
#                       character    n
# 1614615             Joe Maloney  2.0
# 1614613            Paul Maclean  2.0
# 1614657            Rory Devaney  2.0
# 1614658  Francis Austin McGuire  2.0
# 1614623            Tyler Durden  2.0

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EXERCISE</b>:
#
#  <ul>
#   <li>Récupérer l'ensemble des filmes de Morgane Freeman entre 1980 et 2000.</li>
# </ul>
# </div>

# %%
cast[cast["name"].str.startswith('Morgan Free')] #### Nom de l'acteur Morgan Freeman
# Out:
#                                            title  year            name   type  \
# 686206                          10 Items or Less  2006  Morgan Freeman  actor
# 686207                              5 Flights Up  2014  Morgan Freeman  actor
# 686208                         A Man Called Adam  1966  Morgan Freeman  actor
# 686209                       Along Came a Spider  2001  Morgan Freeman  actor
# 686210                                   Amistad  1997  Morgan Freeman  actor
# ...                                          ...   ...             ...    ...
# 686278                                 Unleashed  2005  Morgan Freeman  actor
# 686279                                    Wanted  2008  Morgan Freeman  actor
# 686280                         War of the Worlds  2005  Morgan Freeman  actor
# 686281  Where Were You When the Lights Went Out?  1968  Morgan Freeman  actor
# 686282          Who Says I Can't Ride a Rainbow!  1971  Morgan Freeman  actor
#
# ...

# %%
cast[cast["name"].str.startswith('Morgan Free')].loc[:,"name"].unique() #### Nom de l'acteur Morgan Freeman
# Out:
# array(['Morgan Freeman'], dtype=object)

# %%
#### But: Récuperer l'ensemble des films de Morgane Freeman

cast[cast["name"] =="Morgan Freeman"] #### Films de Morgane nfreeman

#cast[cast["name"].str.startswith('Morgan Free')] #### Ensemble des filsm de Morgane Freeman
# Out:
#                                            title  year            name   type  \
# 686206                          10 Items or Less  2006  Morgan Freeman  actor
# 686207                              5 Flights Up  2014  Morgan Freeman  actor
# 686208                         A Man Called Adam  1966  Morgan Freeman  actor
# 686209                       Along Came a Spider  2001  Morgan Freeman  actor
# 686210                                   Amistad  1997  Morgan Freeman  actor
# ...                                          ...   ...             ...    ...
# 686278                                 Unleashed  2005  Morgan Freeman  actor
# 686279                                    Wanted  2008  Morgan Freeman  actor
# 686280                         War of the Worlds  2005  Morgan Freeman  actor
# 686281  Where Were You When the Lights Went Out?  1968  Morgan Freeman  actor
# 686282          Who Says I Can't Ride a Rainbow!  1971  Morgan Freeman  actor
#
# ...

# %% [markdown]
# Ensemble des acteurs qui s'appelle Morgane Freeman entre 1980 et 2000
#
#
# * Première condition --> Nom: Morgane Freeman
# * Deuxième condition --> year >= 1980
# * Troisième condition --> year =< 2000

# %%
cast[cast["name"] =="Morgan Freeman"] ### condition 1
# Out:
#                                            title  year            name   type  \
# 686206                          10 Items or Less  2006  Morgan Freeman  actor
# 686207                              5 Flights Up  2014  Morgan Freeman  actor
# 686208                         A Man Called Adam  1966  Morgan Freeman  actor
# 686209                       Along Came a Spider  2001  Morgan Freeman  actor
# 686210                                   Amistad  1997  Morgan Freeman  actor
# ...                                          ...   ...             ...    ...
# 686278                                 Unleashed  2005  Morgan Freeman  actor
# 686279                                    Wanted  2008  Morgan Freeman  actor
# 686280                         War of the Worlds  2005  Morgan Freeman  actor
# 686281  Where Were You When the Lights Went Out?  1968  Morgan Freeman  actor
# 686282          Who Says I Can't Ride a Rainbow!  1971  Morgan Freeman  actor
#
# ...

# %%
cast[cast["year"] > 1980] ### condition 2 #### Tout les films sortie après 1980
# Out:
#                                      title  year                         name  \
# 0                          Suuri illusioni  1985                       Homo $
# 1           Gangsta Rap: The Glockumentary  2007                    Too $hort
# 2                        Menace II Society  1993                    Too $hort
# 3        Porndogs: The Adventures of Sadie  2009                    Too $hort
# 4                       Stop Pepper Palmer  2014                    Too $hort
# ...                                    ...   ...                          ...
# 3333690                     Stuttur Frakki  1993    Sveinbj?rg ??rhallsd?ttir
# 3333691                            Foxtrot  1988            Lilja ??risd?ttir
# 3333692   Niceland (Population. 1.000.002)  2004    Sigr??ur J?na ??risd?ttir
# 3333693                       U.S.S.S.S...  2003  Krist?n Andrea ??r?ard?ttir
# 3333694                  Bye Bye Blue Bird  1999                 Rosa ? R?gvu
#
# ...

# %%
cast[cast["year"] <= 2000] ### condition 3 #### Tout les films sortie après 1980
# Out:
#                      title  year                         name     type  \
# 0          Suuri illusioni  1985                       Homo $    actor
# 2        Menace II Society  1993                    Too $hort    actor
# 10              Mixing Nia  1998   Michael 'babeepower' Viera    actor
# 11        The Replacements  2000            Steven 'Bear'Boyd    actor
# 24       Pelotazo nacional  1993              F?lix 'El Gato'    actor
# ...                    ...   ...                          ...      ...
# 3333683              Agnes  1995    Ingibj?rg ?orsteinsd?ttir  actress
# 3333685            Dansinn  1998  Lilja Gu?r?n ?orvaldsd?ttir  actress
# 3333690     Stuttur Frakki  1993    Sveinbj?rg ??rhallsd?ttir  actress
# 3333691            Foxtrot  1988            Lilja ??risd?ttir  actress
# 3333694  Bye Bye Blue Bird  1999                 Rosa ? R?gvu  actress
#
#                                        character     n
# 0                                         Guests  22.0
# ...

# %%
#### Grouper les 3 conditions

cast[(cast["name"]=="Morgan Freeman")&(cast["year"] > 1980)&(cast["year"] <= 2000)] ### Les filmes de MF de 1980 à 2000
# Out:
#                                 title  year            name   type  \
# 686210                        Amistad  1997  Morgan Freeman  actor
# 686217                 Chain Reaction  1996  Morgan Freeman  actor
# 686218                Clean and Sober  1988  Morgan Freeman  actor
# 686220                    Deep Impact  1998  Morgan Freeman  actor
# 686224             Driving Miss Daisy  1989  Morgan Freeman  actor
# 686227                     Eyewitness  1981  Morgan Freeman  actor
# 686229                          Glory  1989  Morgan Freeman  actor
# 686231                      Hard Rain  1998  Morgan Freeman  actor
# 686232                    Harry & Son  1984  Morgan Freeman  actor
# 686236                Johnny Handsome  1989  Morgan Freeman  actor
# 686237                 Kiss the Girls  1997  Morgan Freeman  actor
# 686240                     Lean on Me  1989  Morgan Freeman  actor
# 686245                          Marie  1985  Morgan Freeman  actor
# ...

# %%
cast[(cast["name"]=="Morgan Freeman")&(cast["year"] > 1980)&(cast["year"] <= 2000)].sort_values("year") #### trie par year: Trie qui est croissant
# Out:
#                                 title  year            name   type  \
# 686227                     Eyewitness  1981  Morgan Freeman  actor
# 686232                    Harry & Son  1984  Morgan Freeman  actor
# 686258                       Teachers  1984  Morgan Freeman  actor
# 686245                          Marie  1985  Morgan Freeman  actor
# 686260   That Was Then... This Is Now  1985  Morgan Freeman  actor
# 686257                   Street Smart  1987  Morgan Freeman  actor
# 686218                Clean and Sober  1988  Morgan Freeman  actor
# 686224             Driving Miss Daisy  1989  Morgan Freeman  actor
# 686229                          Glory  1989  Morgan Freeman  actor
# 686236                Johnny Handsome  1989  Morgan Freeman  actor
# 686240                     Lean on Me  1989  Morgan Freeman  actor
# 686262    The Bonfire of the Vanities  1990  Morgan Freeman  actor
# 686255  Robin Hood: Prince of Thieves  1991  Morgan Freeman  actor
# ...

# %%
cast[(cast["name"]=="Morgan Freeman")&(cast["year"] > 1980)&(cast["year"] <= 2000)].sort_values("year", ascending = False) #### trie par year: Trie qui est croissant
# Out:
#                                 title  year            name   type  \
# 686276                Under Suspicion  2000  Morgan Freeman  actor
# 686250                    Nurse Betty  2000  Morgan Freeman  actor
# 686231                      Hard Rain  1998  Morgan Freeman  actor
# 686220                    Deep Impact  1998  Morgan Freeman  actor
# 686210                        Amistad  1997  Morgan Freeman  actor
# 686237                 Kiss the Girls  1997  Morgan Freeman  actor
# 686217                 Chain Reaction  1996  Morgan Freeman  actor
# 686247                  Moll Flanders  1996  Morgan Freeman  actor
# 686256                          Se7en  1995  Morgan Freeman  actor
# 686253                       Outbreak  1995  Morgan Freeman  actor
# 686272       The Shawshank Redemption  1994  Morgan Freeman  actor
# 686271               The Power of One  1992  Morgan Freeman  actor
# 686277                     Unforgiven  1992  Morgan Freeman  actor
# ...
